# %%
import turtle

board = turtle.Turtle()

board.setpos(0,0)
board.circle(50)
board.left(90)
board.forward(50)
board.right(90)

board.forward(50)
board.backward(50)
board.left(15)
board.forward(50)
board.backward(50)
board.left(15)
board.forward(50)
board.backward(50)
board.left(15)
board.forward(50)
board.backward(50)
board.left(15)
board.forward(50)
board.backward(50)
board.left(15)
board.forward(50)
board.backward(50)
board.left(15)
board.forward(50)
board.backward(50)
board.left(15)
board.forward(50)
board.backward(50)
board.left(15)
board.forward(50)
board.backward(50)
board.left(15)
board.forward(50)
board.backward(50)
board.left(15)
board.forward(50)
board.backward(50)
board.left(15)
board.forward(50)
board.backward(50)
board.left(15)
board.forward(50)
board.backward(50)
board.left(15)
board.forward(50)
board.backward(50)
board.left(15)
board.forward(50)
board.backward(50)
board.left(15)
board.forward(50)
board.backward(50)
board.left(15)
board.forward(50)
board.backward(50)
board.left(15)
board.forward(50)
board.backward(50)
board.left(15)
board.forward(50)
board.backward(50)
board.left(15)
board.forward(50)
board.backward(50)
board.left(15)
board.forward(50)
board.backward(50)
board.left(15)
board.forward(50)
board.backward(50)
board.left(15)
board.forward(50)
board.backward(50)
board.left(15)
board.forward(50)
board.backward(50)
board.left(15)

board.right(90)
board.forward(50)

board.left(90)
board.forward(250)
board.left(90)
board.forward(200)

board.left(90)
board.forward(500)
board.left(90)
board.forward(300)
board.left(90)
board.forward(500)

board.left(90)
board.forward(100)


board.left(90)
board.forward(500)
board.right(90)
board.forward(100)
board.right(90)
board.forward(500)
board.right(90)
board.forward(100)
board.right(90)
board.forward(500)

    
    

turtle.done()
